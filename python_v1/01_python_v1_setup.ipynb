# %%
import pandas as pd

# %%
stg_job_list = pd.read_csv(
    "../data/staging/stg_job_list.csv"
)

stg_job_list.head()
# Out:
#    job_id building_id                  job_description  service_id project_id  \
# 0  22-029        K014  LAP Construction Phase Services       85451    P026159
# 1  22-079        Q189           PO 18 Asbestos Service       86933     133460
# 2  23-056        R455           PO 18 Asbestos Service       88731     135678
# 3  24-114        M180           PO 18 Asbestos Service       93632     141149
# 4  25-010        X107           PO 18 Asbestos Service       94758     141770
#
#   contract_no job_status
# 0      CT-002   Complete
# 1      CT-002   Complete
# 2      CT-002   Complete
# 3      CT-002   Complete
# 4      CT-002   Complete
